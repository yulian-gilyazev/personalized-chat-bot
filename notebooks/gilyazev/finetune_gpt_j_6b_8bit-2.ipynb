# %% [markdown]
# <a href="https://colab.research.google.com/github/yulian-gilyazev/colab-notebooks/blob/main/inetune_gpt_j_6b_8bit-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Fine-tuning 6-Billion GPT-J in colab with LoRA and 8-bit compression
#
# This notebook is a proof of concept for fine-tuning [GPT-J-6B](https://huggingface.co/EleutherAI/gpt-j-6B) with limited memory. A detailed explanation of how it works can be found in [this model card](https://huggingface.co/hivemind/gpt-j-6B-8bit).

# %%
# !pip install transformers==4.14.1
# !pip install bitsandbytes
# !pip install datasets==1.16.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.14.1
#   Downloading transformers-4.14.1-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 7.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (1.21.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 70.5 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 42.1 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 64.0 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (4.64.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.1) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.14.1) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.14.1) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.14.1) (3.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.1) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.1) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.14.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.14.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.14.1) (1.2.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=d0283a70250c888286120b77b70c3782dc399ad2e3dfde10c2d9db350838a1d6
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 sacremoses-0.0.53 tokenizers-0.10.3 transformers-4.14.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.35.0-py3-none-any.whl (62.5 MB)
#      |████████████████████████████████| 62.5 MB 1.2 MB/s
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.35.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets==1.16.1
#   Downloading datasets-1.16.1-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 6.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (5.0.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 45.9 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (3.8.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (1.21.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (2.23.0)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 63.0 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (4.64.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (2022.8.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (0.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (21.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (0.3.5.1)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.16.1) (6.0.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (4.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.16.1) (4.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.16.1) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.16.1) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.16.1) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.16.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.16.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.16.1) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.16.1) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets==1.16.1) (3.9.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.16.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.16.1) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.16.1) (1.15.0)
# Installing collected packages: xxhash, multiprocess, datasets
# Successfully installed datasets-1.16.1 multiprocess-0.70.13 xxhash-3.0.0

# %%
import transformers

import torch
import torch.nn.functional as F
from torch import nn
from torch.cuda.amp import custom_fwd, custom_bwd

from bitsandbytes.functional import quantize_blockwise, dequantize_blockwise

from tqdm.auto import tqdm
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 112
# CUDA SETUP: Loading binary /usr/local/lib/python3.7/dist-packages/bitsandbytes/libbitsandbytes_cuda112.so...
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:106: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   f'{candidate_env_vars["LD_LIBRARY_PATH"]} did not contain '
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:28: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('"/usr/local/bin/dap_multiplexer","enableLsp"'), PosixPath('true}'), PosixPath('["--ip=172.28.0.2"],"debugAdapterMultiplexerPath"'), PosixPath('6000,"kernelManagerProxyHost"'), PosixPath('"172.28.0.3","jupyterArgs"'), PosixPath('{"kernelManagerProxyPort"')}
#   "WARNING: The following directories listed in your path were found to "
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:28: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   "WARNING: The following directories listed in your path were found to "
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:28: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   "WARNING: The following directories listed in your path were found to "

# %% [markdown]
# ### Converting the model to 8 bits.
#
# We convert EleutherAI's GPT-J-6B model to 8 bits using facebook's [bitsandbytes](https://github.com/facebookresearch/bitsandbytes) library. This reduces the model's size from 20Gb down to just 6Gb.
#
# Note that we don't convert linear layer biases to 8 bit as they take up less that 1% of the model's weight anyway.

# %%
class FrozenBNBLinear(nn.Module):
    def __init__(self, weight, absmax, code, bias=None):
        assert isinstance(bias, nn.Parameter) or bias is None
        super().__init__()
        self.out_features, self.in_features = weight.shape
        self.register_buffer("weight", weight.requires_grad_(False))
        self.register_buffer("absmax", absmax.requires_grad_(False))
        self.register_buffer("code", code.requires_grad_(False))
        self.adapter = None
        self.bias = bias
 
    def forward(self, input):
        output = DequantizeAndLinear.apply(input, self.weight, self.absmax, self.code, self.bias)
        if self.adapter:
            output = output + self.adapter(input)
        return output
 
    @classmethod
    def from_linear(cls, linear: nn.Linear) -> "FrozenBNBLinear":
        weights_int8, state = quantize_blockise_lowmemory(linear.weight)
        return cls(weights_int8, *state, linear.bias)
 
    def __repr__(self):
        return f"{self.__class__.__name__}({self.in_features}, {self.out_features})"
 
 
class DequantizeAndLinear(torch.autograd.Function): 
    @staticmethod
    @custom_fwd
    def forward(ctx, input: torch.Tensor, weights_quantized: torch.ByteTensor,
                absmax: torch.FloatTensor, code: torch.FloatTensor, bias: torch.FloatTensor):
        weights_deq = dequantize_blockwise(weights_quantized, absmax=absmax, code=code)
        ctx.save_for_backward(input, weights_quantized, absmax, code)
        ctx._has_bias = bias is not None
        return F.linear(input, weights_deq, bias)
 
    @staticmethod
    @custom_bwd
    def backward(ctx, grad_output: torch.Tensor):
        assert not ctx.needs_input_grad[1] and not ctx.needs_input_grad[2] and not ctx.needs_input_grad[3]
        input, weights_quantized, absmax, code = ctx.saved_tensors
        # grad_output: [*batch, out_features]
        weights_deq = dequantize_blockwise(weights_quantized, absmax=absmax, code=code)
        grad_input = grad_output @ weights_deq
        grad_bias = grad_output.flatten(0, -2).sum(dim=0) if ctx._has_bias else None
        return grad_input, None, None, None, grad_bias
 
 
class FrozenBNBEmbedding(nn.Module):
    def __init__(self, weight, absmax, code):
        super().__init__()
        self.num_embeddings, self.embedding_dim = weight.shape
        self.register_buffer("weight", weight.requires_grad_(False))
        self.register_buffer("absmax", absmax.requires_grad_(False))
        self.register_buffer("code", code.requires_grad_(False))
        self.adapter = None
 
    def forward(self, input, **kwargs):
        with torch.no_grad():
            # note: both quantuized weights and input indices are *not* differentiable
            weight_deq = dequantize_blockwise(self.weight, absmax=self.absmax, code=self.code)
            output = F.embedding(input, weight_deq, **kwargs)
        if self.adapter:
            output += self.adapter(input)
        return output 
 
    @classmethod
    def from_embedding(cls, embedding: nn.Embedding) -> "FrozenBNBEmbedding":
        weights_int8, state = quantize_blockise_lowmemory(embedding.weight)
        return cls(weights_int8, *state)
 
    def __repr__(self):
        return f"{self.__class__.__name__}({self.num_embeddings}, {self.embedding_dim})"
 
 
def quantize_blockise_lowmemory(matrix: torch.Tensor, chunk_size: int = 2 ** 20):
    assert chunk_size % 4096 == 0
    code = None
    chunks = []
    absmaxes = []
    flat_tensor = matrix.view(-1)
    for i in range((matrix.numel() - 1) // chunk_size + 1):
        input_chunk = flat_tensor[i * chunk_size: (i + 1) * chunk_size].clone()
        quantized_chunk, (absmax_chunk, code) = quantize_blockwise(input_chunk, code=code)
        chunks.append(quantized_chunk)
        absmaxes.append(absmax_chunk)
 
    matrix_i8 = torch.cat(chunks).reshape_as(matrix)
    absmax = torch.cat(absmaxes)
    return matrix_i8, (absmax, code)
 
 
def convert_to_int8(model):
    """Convert linear and embedding modules to 8-bit with optional adapters"""
    for module in list(model.modules()):
        for name, child in module.named_children():
            if isinstance(child, nn.Linear):
                print(name, child)
                setattr( 
                    module,
                    name,
                    FrozenBNBLinear(
                        weight=torch.zeros(child.out_features, child.in_features, dtype=torch.uint8),
                        absmax=torch.zeros((child.weight.numel() - 1) // 4096 + 1),
                        code=torch.zeros(256),
                        bias=child.bias,
                    ),
                )
            elif isinstance(child, nn.Embedding):
                setattr(
                    module,
                    name,
                    FrozenBNBEmbedding(
                        weight=torch.zeros(child.num_embeddings, child.embedding_dim, dtype=torch.uint8),
                        absmax=torch.zeros((child.weight.numel() - 1) // 4096 + 1),
                        code=torch.zeros(256),
                    )
                )

# %%
class GPTJBlock(transformers.models.gptj.modeling_gptj.GPTJBlock):
    def __init__(self, config):
        super().__init__(config)

        convert_to_int8(self.attn)
        convert_to_int8(self.mlp)


class GPTJModel(transformers.models.gptj.modeling_gptj.GPTJModel):
    def __init__(self, config):
        super().__init__(config)
        convert_to_int8(self)
        

class GPTJForCausalLM(transformers.models.gptj.modeling_gptj.GPTJForCausalLM):
    def __init__(self, config):
        super().__init__(config)
        convert_to_int8(self)


transformers.models.gptj.modeling_gptj.GPTJBlock = GPTJBlock  # monkey-patch GPT-J

# %%
config = transformers.GPTJConfig.from_pretrained("EleutherAI/gpt-j-6B")
tokenizer = transformers.AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")
# Out:
# Downloading:   0%|          | 0.00/930 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/619 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/779k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.94k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]

# %%
gpt = GPTJForCausalLM.from_pretrained("hivemind/gpt-j-6B-8bit", low_cpu_mem_usage=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
gpt.to(device)
# Out:
# Downloading:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.75G [00:00<?, ?B/s]
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# lm_head Linear(in_features=4096, out_features=50400, bias=True)
# GPTJForCausalLM(
#   (transformer): GPTJModel(
#     (wte): FrozenBNBEmbedding(50400, 4096)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (6): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (7): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (8): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (9): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (10): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (11): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (12): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (13): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (14): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (15): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (16): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (17): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (18): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (19): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (20): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (21): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (22): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (23): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (24): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (25): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (26): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (27): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): FrozenBNBLinear(4096, 50400)
# )

# %% [markdown]
# ### Text generation example

# %%
prompt = tokenizer("A cat sat on a mat", return_tensors='pt')
prompt = {key: value.to(device) for key, value in prompt.items()}
out = gpt.generate(**prompt, min_length=128, max_length=128, do_sample=True)
tokenizer.decode(out[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'A cat sat on a mat in front of me. The cat’s coat was the color of mahogany, but it still glowed in the dim light, so even though the mat was a pale yellow, the cat’s black eyes shone. The cat fixed me with its brown gaze.\n\nI had been in the apartment for about five hours. The apartment was about two rooms in size, and was occupied by a family with two young children, a toddler and a preschool boy. The two children and their four siblings shared two rooms, and the parents slept with one of the children in one of the rooms'

# %% [markdown]
# ### LoRA fine-tuning example
# Here we demonstrate how to fine-tune the proposed model using low-rank adapters [(Hu et al, 2021)](https://arxiv.org/abs/2106.09685) and [8-bit Adam](https://arxiv.org/abs/2110.02861). We also use [dataset streaming API](https://huggingface.co/docs/datasets/dataset_streaming.html) to avoid downloading the large dataset.

# %%
class CopyTensor(nn.Module):
  def __init__(self):
    super().__init__()
  def forward(self, X):
    return X.clone()

def add_adapters(model, adapter_dim=16):
    assert adapter_dim > 0

    for module in model.modules():
        if isinstance(module, FrozenBNBLinear):
            module.adapter = nn.Sequential(
                nn.Linear(module.in_features, adapter_dim, bias=False),
                nn.Linear(adapter_dim, module.out_features, bias=False),
            )
            nn.init.zeros_(module.adapter[1].weight)
        elif isinstance(module, FrozenBNBEmbedding):
            module.adapter = nn.Sequential(
                nn.Embedding(module.num_embeddings, adapter_dim),
                nn.Linear(adapter_dim, module.embedding_dim, bias=False),
            )
            nn.init.zeros_(module.adapter[1].weight)

add_adapters(gpt)
gpt.to(device)

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
def plot_metrics(metrics_dict, last_to_show=30):
    n = len(metrics_dict)
    clear_output(True)
    plt.figure(figsize=(20, 10))
    for i, (metric_name, metric_values) in enumerate(metrics_dict.items()):
        plt.subplot(2, n, i + 1)
        plt.title(metric_name)
        plt.plot(metric_values, label=metric_name)
        plt.legend()
    for i, (metric_name, metric_values) in enumerate(metrics_dict.items()):
        plt.subplot(2, n, n + i + 1)
        plt.title(f'{metric_name} last {last_to_show} values')
        plt.plot(metric_values[-last_to_show:], label=metric_name)
        plt.legend()
    plt.show()

# %%
params_for_optimizer = [
    name for name, param in gpt.named_parameters()
    if "attn" in name and "adapter" in name
]
print("Trainiable params:", len(params_for_optimizer))
# Out:
# Trainiable params: 224

# %%
# and after you verified it:
for name, param in gpt.named_parameters():
    if name not in params_for_optimizer:
        print(f"Setting {name} requires_grad=False")
        param.requires_grad = False
    else:
        param.requires_grad = True
# Out:
# Setting transformer.wte.adapter.0.weight requires_grad=False
# Setting transformer.wte.adapter.1.weight requires_grad=False
# Setting transformer.h.0.ln_1.weight requires_grad=False
# Setting transformer.h.0.ln_1.bias requires_grad=False
# Setting transformer.h.0.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.0.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.0.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.0.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.0.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.0.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.1.ln_1.weight requires_grad=False
# Setting transformer.h.1.ln_1.bias requires_grad=False
# Setting transformer.h.1.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.1.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.1.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.1.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.1.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.1.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.2.ln_1.weight requires_grad=False
# Setting transformer.h.2.ln_1.bias requires_grad=False
# Setting transformer.h.2.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.2.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.2.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.2.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.2.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.2.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.3.ln_1.weight requires_grad=False
# Setting transformer.h.3.ln_1.bias requires_grad=False
# Setting transformer.h.3.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.3.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.3.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.3.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.3.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.3.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.4.ln_1.weight requires_grad=False
# Setting transformer.h.4.ln_1.bias requires_grad=False
# Setting transformer.h.4.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.4.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.4.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.4.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.4.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.4.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.5.ln_1.weight requires_grad=False
# Setting transformer.h.5.ln_1.bias requires_grad=False
# Setting transformer.h.5.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.5.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.5.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.5.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.5.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.5.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.6.ln_1.weight requires_grad=False
# Setting transformer.h.6.ln_1.bias requires_grad=False
# Setting transformer.h.6.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.6.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.6.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.6.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.6.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.6.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.7.ln_1.weight requires_grad=False
# Setting transformer.h.7.ln_1.bias requires_grad=False
# Setting transformer.h.7.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.7.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.7.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.7.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.7.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.7.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.8.ln_1.weight requires_grad=False
# Setting transformer.h.8.ln_1.bias requires_grad=False
# Setting transformer.h.8.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.8.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.8.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.8.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.8.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.8.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.9.ln_1.weight requires_grad=False
# Setting transformer.h.9.ln_1.bias requires_grad=False
# Setting transformer.h.9.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.9.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.9.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.9.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.9.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.9.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.10.ln_1.weight requires_grad=False
# Setting transformer.h.10.ln_1.bias requires_grad=False
# Setting transformer.h.10.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.10.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.10.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.10.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.10.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.10.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.11.ln_1.weight requires_grad=False
# Setting transformer.h.11.ln_1.bias requires_grad=False
# Setting transformer.h.11.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.11.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.11.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.11.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.11.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.11.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.12.ln_1.weight requires_grad=False
# Setting transformer.h.12.ln_1.bias requires_grad=False
# Setting transformer.h.12.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.12.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.12.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.12.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.12.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.12.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.13.ln_1.weight requires_grad=False
# Setting transformer.h.13.ln_1.bias requires_grad=False
# Setting transformer.h.13.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.13.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.13.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.13.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.13.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.13.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.14.ln_1.weight requires_grad=False
# Setting transformer.h.14.ln_1.bias requires_grad=False
# Setting transformer.h.14.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.14.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.14.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.14.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.14.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.14.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.15.ln_1.weight requires_grad=False
# Setting transformer.h.15.ln_1.bias requires_grad=False
# Setting transformer.h.15.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.15.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.15.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.15.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.15.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.15.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.16.ln_1.weight requires_grad=False
# Setting transformer.h.16.ln_1.bias requires_grad=False
# Setting transformer.h.16.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.16.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.16.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.16.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.16.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.16.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.17.ln_1.weight requires_grad=False
# Setting transformer.h.17.ln_1.bias requires_grad=False
# Setting transformer.h.17.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.17.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.17.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.17.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.17.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.17.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.18.ln_1.weight requires_grad=False
# Setting transformer.h.18.ln_1.bias requires_grad=False
# Setting transformer.h.18.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.18.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.18.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.18.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.18.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.18.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.19.ln_1.weight requires_grad=False
# Setting transformer.h.19.ln_1.bias requires_grad=False
# Setting transformer.h.19.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.19.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.19.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.19.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.19.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.19.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.20.ln_1.weight requires_grad=False
# Setting transformer.h.20.ln_1.bias requires_grad=False
# Setting transformer.h.20.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.20.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.20.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.20.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.20.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.20.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.21.ln_1.weight requires_grad=False
# Setting transformer.h.21.ln_1.bias requires_grad=False
# Setting transformer.h.21.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.21.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.21.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.21.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.21.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.21.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.22.ln_1.weight requires_grad=False
# Setting transformer.h.22.ln_1.bias requires_grad=False
# Setting transformer.h.22.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.22.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.22.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.22.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.22.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.22.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.23.ln_1.weight requires_grad=False
# Setting transformer.h.23.ln_1.bias requires_grad=False
# Setting transformer.h.23.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.23.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.23.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.23.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.23.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.23.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.24.ln_1.weight requires_grad=False
# Setting transformer.h.24.ln_1.bias requires_grad=False
# Setting transformer.h.24.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.24.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.24.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.24.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.24.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.24.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.25.ln_1.weight requires_grad=False
# Setting transformer.h.25.ln_1.bias requires_grad=False
# Setting transformer.h.25.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.25.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.25.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.25.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.25.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.25.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.26.ln_1.weight requires_grad=False
# Setting transformer.h.26.ln_1.bias requires_grad=False
# Setting transformer.h.26.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.26.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.26.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.26.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.26.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.26.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.h.27.ln_1.weight requires_grad=False
# Setting transformer.h.27.ln_1.bias requires_grad=False
# Setting transformer.h.27.mlp.fc_in.bias requires_grad=False
# Setting transformer.h.27.mlp.fc_in.adapter.0.weight requires_grad=False
# Setting transformer.h.27.mlp.fc_in.adapter.1.weight requires_grad=False
# Setting transformer.h.27.mlp.fc_out.bias requires_grad=False
# Setting transformer.h.27.mlp.fc_out.adapter.0.weight requires_grad=False
# Setting transformer.h.27.mlp.fc_out.adapter.1.weight requires_grad=False
# Setting transformer.ln_f.weight requires_grad=False
# Setting transformer.ln_f.bias requires_grad=False
# Setting lm_head.bias requires_grad=False
# Setting lm_head.adapter.0.weight requires_grad=False
# Setting lm_head.adapter.1.weight requires_grad=False

# %%
from datasets import load_dataset

dataset = load_dataset("bavard/personachat_truecased", streaming=True)
# Out:
# Downloading:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.47k [00:00<?, ?B/s]
# WARNING:datasets.builder:No config specified, defaulting to: personachat_truecased/full

# %%
import itertools
import pandas as pd
import numpy as np

# %%
dummy_persona_chat_ds = pd.DataFrame(itertools.islice(dataset['train'], 0, 1000))

# %%
dummy_persona_chat_ds.iloc[0]['candidates']
# Out:
# ['My mom was single with 3 boys, so we never left the projects.',
#  'I try to wear all black every day. It makes me feel comfortable.',
#  'Well nursing stresses you out so I wish luck with sister.',
#  'Yeah just want to pick up Nba nfl getting old.',
#  'I really like Celine Dion. What about you?',
#  'No. I live near farms.',
#  "I wish I had a daughter, I'm a boy mom. They're beautiful boys though still lucky.",
#  'Yeah when I get bored I play gone with the wind my favorite movie.',
#  "Hi how are you? I'm eating dinner with my hubby and 2 kids.",
#  'Were you married to your high school sweetheart? I was.',
#  'That is great to hear! Are you a competitive rider?',
#  "Hi, I'm doing ok. I'm a banker. How about you?",
#  "I'm 5 years old.",
#  'Hi there. How are you today?',
#  'I totally understand how stressful that can be.',
#  'Yeah sometimes you do not know what you are actually watching.',
#  'Mother taught me to cook! We are looking for an exterminator.',
#  'I enjoy romantic movie. What is your favorite season? Mine is summer.',
#  'Editing photos takes a lot of work.',
#  'You must be very fast. Hunting is one of my favorite hobbies.']

# %%
dummy_persona_chat_ds.iloc[1]['personality'], dummy_persona_chat_ds.iloc[2]['history'],
# Out:
# (['I like to remodel homes.',
#   'I like to go hunting.',
#   'I like to shoot a bow.',
#   'My favorite holiday is halloween.'],
#  ["Hi, how are you doing? I'm getting ready to do some cheetah chasing to stay in shape.",
#   'You must be very fast. Hunting is one of my favorite hobbies.',
#   'I am! For my hobby I like to do canning or some whittling.',
#   'I also remodel homes when I am not out bow hunting.',
#   "That's neat. When I was in high school I placed 6th in 100m dash!"])

# %%
from transformers.utils.dummy_pt_objects import ReformerModelWithLMHead
class PersonaChatDataSet:
    def __init__(self, row_dataset):
        self.row_dataset = row_dataset

    def __len__(self):
        return len(self.dataset)

    def _shuffle(self):
        self.indexes = np.arange(0, self.__len__())
        np.random.shuffle(self.indexes)

    def __getitem__(self, idx):
        row = self.row_dataset.iloc[self.indexes[idx]]
        return row

    def groupby(self, cols):
        grouped_ds = self.row_dataset.groupby(cols)
        return

# %%
class InferenceWithPromptGenerator:
    def __init__(self, model=gpt, tokenizer=tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        self.max_length = 512
        self.seq_length = 128
    def generate(self, personality, history):
        for i in range(1, 10):
            prompt_s = ' '.join(personality) + '\n' + '\n'.join([f'B:{item}' if i % 2 else f'A:{item}' for i, item in enumerate(history[:-i])])
            if len(prompt_s) > self.max_length:
                if len(history) > i + 1:
                    continue
                else:
                    break
            else:
                break
        prompt = self.tokenizer(prompt_s, return_tensors='pt')
        prompt = {key: value.to(device) for key, value in prompt.items()}
        out = gpt.generate(**prompt, min_length=len(prompt) + self.seq_length // 4, max_length=len(prompt) + self.seq_length, do_sample=True)
        return self.tokenizer.decode(out[0]), prompt_s

# %%
generator = InferenceWithPromptGenerator()

# %%
result, prompt = generator.generate(dummy_persona_chat_ds.iloc[50]['personality'], dummy_persona_chat_ds.iloc[50]['history'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result, '\n' * 4, prompt)
# Out:
# I like to remodel homes. I like to go hunting. I like to shoot a bow. My favorite holiday is halloween.
# A:Hi, how are you doing? I'm getting ready to do some cheetah chasing to stay in shape.
# B:You must be very fast. Hunting is one of my favorite hobbies. I hunt my deer, pheasant, and turkey. A:It's a good sport on a beautiful spring day. What do you think you'll do for the holiday this year?
# B:Halloween is one of my favorite holidays. I dress up in my favorite costume and go
#
#
#
#  I like to remodel homes. I like to go hunting. I like to shoot a bow. My favorite holiday is halloween.
# A:Hi, how are you doing? I'm getting ready to do some cheetah chasing to stay in shape.
# B:You must be very fast. Hunting is one of my favorite hobbies.

# %%
def generate_prompt(personality, history, candidates)

# %%
dummy_persona_chat_ds.head(50)
# Out:
#                                           personality  \
# 0   [I like to remodel homes., I like to go huntin...
# 1   [I like to remodel homes., I like to go huntin...
# 2   [I like to remodel homes., I like to go huntin...
# 3   [I like to remodel homes., I like to go huntin...
# 4   [I like to remodel homes., I like to go huntin...
# 5   [I like to remodel homes., I like to go huntin...
# 6   [I like to remodel homes., I like to go huntin...
# 7   [My mom is my best friend., I have four sister...
# 8   [My mom is my best friend., I have four sister...
# 9   [My mom is my best friend., I have four sister...
# 10  [My mom is my best friend., I have four sister...
# 11  [My mom is my best friend., I have four sister...
# 12  [My mom is my best friend., I have four sister...
# 13  [My mom is my best friend., I have four sister...
# 14  [I had a gig at local theater last night., I w...
# 15  [I had a gig at local theater last night., I w...
# 16  [I had a gig at local theater last night., I w...
# 17  [I had a gig at local theater last night., I w...
# 18  [I had a gig at local theater last night., I w...
# 19  [I had a gig at local theater last night., I w...
# 20  [I'm very athletic., I wear contacts., I have ...
# 21  [I'm very athletic., I wear contacts., I have ...
# 22  [I'm very athletic., I wear contacts., I have ...
# 23  [I'm very athletic., I wear contacts., I have ...
# 24  [I'm very athletic., I wear contacts., I have ...
# 25  [I'm very athletic., I wear contacts., I have ...
# 26  [I'm very athletic., I wear contacts., I have ...
# 27  [I'm very athletic., I wear contacts., I have ...
# 28  [I am primarily a meat eater., I am a guitar p...
# 29  [I am primarily a meat eater., I am a guitar p...
# 30  [I am primarily a meat eater., I am a guitar p...
# 31  [I am primarily a meat eater., I am a guitar p...
# 32  [I am primarily a meat eater., I am a guitar p...
# 33  [I am primarily a meat eater., I am a guitar p...
# 34  [I am primarily a meat eater., I am a guitar p...
# 35  [I own a hearse., I love to crochet., I like a...
# 36  [I own a hearse., I love to crochet., I like a...
# 37  [I own a hearse., I love to crochet., I like a...
# 38  [I own a hearse., I love to crochet., I like a...
# 39  [I own a hearse., I love to crochet., I like a...
# 40  [I own a hearse., I love to crochet., I like a...
# 41  [I own a hearse., I love to crochet., I like a...
# 42  [I own a hearse., I love to crochet., I like a...
# 43  [I have a boxer dog., I like baths., I like to...
# 44  [I have a boxer dog., I like baths., I like to...
# 45  [I have a boxer dog., I like baths., I like to...
# 46  [I have a boxer dog., I like baths., I like to...
# 47  [I have a boxer dog., I like baths., I like to...
# 48  [I have a boxer dog., I like baths., I like to...
# 49  [I have a boxer dog., I like baths., I like to...
#
#                                            candidates  \
# 0   [My mom was single with 3 boys, so we never le...
# 1   [Hello I am doing well how are you?, Ll someth...
# 2   [Yes they do but I say no to them lol., I have...
# 3   [Not really, it is just a small local radio st...
# 4   [I am listening to system of a down, I wonder ...
# 5   [That sounds nice. Do you make your own?, I ha...
# 6   [Awesome. So what do you do for a living?, You...
# 7   [There was one person better than me, but I wi...
# 8   [That would be great. What do you do on the we...
# 9   [Very long, she was with me when I colored my ...
# 10  [Hi there, I'm Bob., I know a bit about food. ...
# 11  [Love that too. I'm waiting on my car to be fi...
# 12  [Hello, I play with my iguanas and dogs., Ok s...
# 13  [What sort of events do you normally photograp...
# 14  [Fine how are you feeling tonight?, I like to ...
# 15  [I like to play football are you like football...
# 16  [My 4 dogs do not mind them tho. We are always...
# 17  [Hey there, where are you from?, That could ha...
# 18  [Yes. Honesty is key. And share pita bread. Ha...
# 19  [Hello how are you tonight., What do you do fo...
# 20  [Cool, I'm currently studying and enjoy going ...
# 21  [Yes, been married for about twelve years, two...
# 22  [I like reading. My favorite genre are crime n...
# 23  [Hey, how are you doing?, I've been a Christia...
# 24  [I like the nfl as well, no pro teams in new M...
# 25  [I adore beer. I have had 35 different beers i...
# 26  [Hello., I love chicken. I do not eat red meat...
# 27  [I do like to read, but only ebooks. Physical ...
# 28  [Yes, I like the green Bay packers., In Califo...
# 29  [Yes! I should try the desert. I want to taste...
# 30  [What a bummer but ok cool., Sometimes, I like...
# 31  [My kids love sesame street., Nature has a way...
# 32  [That is great to hear! Maybe you can teach me...
# 33  [Do ice cubes satisfy your hunger?, It is a cl...
# 34  [Not much where do you work?, Hello! do you ha...
# 35  [High school students are interesting. You tea...
# 36  [Hi how are you today?, He looks like Thor. I'...
# 37  [Yeah, I want to change the world. What about ...
# 38  [I am from Mexico like the food., I love singi...
# 39  [Nice, I am not much of an athlete but I watch...
# 40  [That sounds amazing, wish I had a woman like ...
# 41  [I'm great, just working on my live action rol...
# 42  [To Asia. Have you ever traveled other countri...
# 43  [Hi I'm great! Just finished up my latest work...
# 44  [Cubs won! You sing and dance? I do. bird peck...
# 45  [I never been, I just moved to Virginia from P...
# 46  [How are you doing today?, I like electronic a...
# 47  [I love the band bon over but my colleagues at...
# 48  [That's insane! Hopefully I can earn more mone...
# 49  [Yeah, I was never a fan of it. My friends pla...
#
#                                               history  conv_id  utterance_idx
# 0   [Hi, how are you doing? I'm getting ready to d...        0              0
# 1   [Hi, how are you doing? I'm getting ready to d...        0              1
# 2   [Hi, how are you doing? I'm getting ready to d...        0              2
# 3   [Hi, how are you doing? I'm getting ready to d...        0              3
# 4   [Hi, how are you doing? I'm getting ready to d...        0              4
# 5   [Hi, how are you doing? I'm getting ready to d...        0              5
# 6   [Hi, how are you doing? I'm getting ready to d...        0              6
# 7                      [Hi, how are you doing today?]        1              0
# 8   [Hi, how are you doing today?, I am spending t...        1              1
# 9   [Hi, how are you doing today?, I am spending t...        1              2
# 10  [Hi, how are you doing today?, I am spending t...        1              3
# 11  [Hi, how are you doing today?, I am spending t...        1              4
# 12  [Hi, how are you doing today?, I am spending t...        1              5
# 13  [Hi, how are you doing today?, I am spending t...        1              6
# 14  [We all live in a yellow submarine, a yellow s...        2              0
# 15  [We all live in a yellow submarine, a yellow s...        2              1
# 16  [We all live in a yellow submarine, a yellow s...        2              2
# 17  [We all live in a yellow submarine, a yellow s...        2              3
# 18  [We all live in a yellow submarine, a yellow s...        2              4
# 19  [We all live in a yellow submarine, a yellow s...        2              5
# 20                    [Hi! I work as a gourmet cook.]        3              0
# 21  [Hi! I work as a gourmet cook., I don't like c...        3              1
# 22  [Hi! I work as a gourmet cook., I don't like c...        3              2
# 23  [Hi! I work as a gourmet cook., I don't like c...        3              3
# 24  [Hi! I work as a gourmet cook., I don't like c...        3              4
# 25  [Hi! I work as a gourmet cook., I don't like c...        3              5
# 26  [Hi! I work as a gourmet cook., I don't like c...        3              6
# 27  [Hi! I work as a gourmet cook., I don't like c...        3              7
# 28                         [How are you doing today.]        4              0
# 29  [How are you doing today., What do you do for ...        4              1
# 30  [How are you doing today., What do you do for ...        4              2
# 31  [How are you doing today., What do you do for ...        4              3
# 32  [How are you doing today., What do you do for ...        4              4
# 33  [How are you doing today., What do you do for ...        4              5
# 34  [How are you doing today., What do you do for ...        4              6
# 35                   [Hello friend, how is it going.]        5              0
# 36  [Hello friend, how is it going., I am well an ...        5              1
# 37  [Hello friend, how is it going., I am well an ...        5              2
# 38  [Hello friend, how is it going., I am well an ...        5              3
# 39  [Hello friend, how is it going., I am well an ...        5              4
# 40  [Hello friend, how is it going., I am well an ...        5              5
# 41  [Hello friend, how is it going., I am well an ...        5              6
# 42  [Hello friend, how is it going., I am well an ...        5              7
# 43  [Rock on, I'm listening to my favorite band gu...        6              0
# 44  [Rock on, I'm listening to my favorite band gu...        6              1
# 45  [Rock on, I'm listening to my favorite band gu...        6              2
# 46  [Rock on, I'm listening to my favorite band gu...        6              3
# 47  [Rock on, I'm listening to my favorite band gu...        6              4
# 48  [Rock on, I'm listening to my favorite band gu...        6              5
# 49  [Rock on, I'm listening to my favorite band gu...        6              6

# %%
for item in dataset['train']:
    print(item)
    break
# Out:
# {'personality': ['I like to remodel homes.', 'I like to go hunting.', 'I like to shoot a bow.', 'My favorite holiday is halloween.'], 'candidates': ['My mom was single with 3 boys, so we never left the projects.', 'I try to wear all black every day. It makes me feel comfortable.', 'Well nursing stresses you out so I wish luck with sister.', 'Yeah just want to pick up Nba nfl getting old.', 'I really like Celine Dion. What about you?', 'No. I live near farms.', "I wish I had a daughter, I'm a boy mom. They're beautiful boys though still lucky.", 'Yeah when I get bored I play gone with the wind my favorite movie.', "Hi how are you? I'm eating dinner with my hubby and 2 kids.", 'Were you married to your high school sweetheart? I was.', 'That is great to hear! Are you a competitive rider?', "Hi, I'm doing ok. I'm a banker. How about you?", "I'm 5 years old.", 'Hi there. How are you today?', 'I totally understand how stressful that can be.', 'Yeah sometimes you do not know what you are actually watching.', 'Mother taught me to cook! We are looking for an exterminator.', 'I enjoy romantic movie. What is your favorite season? Mine is summer.', 'Editing photos takes a lot of work.', 'You must be very fast. Hunting is one of my favorite hobbies.'], 'history': ["Hi, how are you doing? I'm getting ready to do some cheetah chasing to stay in shape."], 'conv_id': 0, 'utterance_idx': 0}

# %%
from datasets import load_dataset
from bitsandbytes.optim import Adam8bit

gpt.gradient_checkpointing_enable()
from datasets import load_dataset

dataset = load_dataset("bavard/personachat_truecased", stre)

codeparrot = load_dataset("transformersbook/codeparrot-train", streaming=True)
optimizer = Adam8bit(gpt.parameters(), lr=1e-5)

metrics_dict = {'loss': []}

with torch.cuda.amp.autocast():
    for row in tqdm(codeparrot["train"]):
        if len(row["content"]) <= 1:
            continue

        batch = tokenizer(row["content"], truncation=True, max_length=128, return_tensors='pt')
        batch = {k: v.cuda() for k, v in batch.items()}

        out = gpt.forward(**batch,)

        loss = F.cross_entropy(out.logits[:, :-1, :].flatten(0, -2), batch['input_ids'][:, 1:].flatten(),
                               reduction='mean')
        metrics_dict['loss'].append(loss.detach().cpu().numpy())
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        plot_metrics(metrics_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-a783e0015078> in <module>
#      17         batch = {k: v.cuda() for k, v in batch.items()}
#      18
# ---> 19         out = gpt.forward(**batch,)
#      20
#      21         loss = F.cross_entropy(out.logits[:, :-1, :].flatten(0, -2), batch['input_ids'][:, 1:].flatten(),
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/gptj/modeling_gptj.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     791             output_attentions=output_attentions,
#     792             output_hidden_states=output_hidden_states,
# --> 793             return_dict=return_dict,
#     794         )
#     795         hidden_states = transformer_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/gptj/modeling_gptj.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     640                     head_mask=head_mask[i],
#     641                     use_cache=use_cache,
# --> 642                     output_attentions=output_attentions,
#     643                 )
#     644
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/gptj/modeling_gptj.py in forward(self, hidden_states, layer_past, attention_mask, head_mask, use_cache, output_attentions)
#     284             head_mask=head_mask,
#     285             use_cache=use_cache,
# --> 286             output_attentions=output_attentions,
#     287         )
#     288         attn_output = attn_outputs[0]  # output_attn: a, present, (attentions)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/gptj/modeling_gptj.py in forward(self, hidden_states, attention_mask, layer_past, head_mask, use_cache, output_attentions)
#     201             q_pass = query[:, :, :, self.rotary_dim :]
#     202
# --> 203             sincos = fixed_pos_embedding(k_rot, 1, seq_len=seq_len)
#     204             k_rot = apply_rotary_pos_emb(k_rot, sincos, offset=offset)
#     205             q_rot = apply_rotary_pos_emb(q_rot, sincos, offset=offset)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/gptj/modeling_gptj.py in fixed_pos_embedding(x, seq_dim, seq_len)
#      53         seq_len = x.shape[seq_dim]
#      54     inv_freq = 1.0 / (10000 ** (torch.arange(0, dim, 2) / dim))
# ---> 55     sinusoid_inp = torch.einsum("i , j -> i j", torch.arange(seq_len), inv_freq).to(x.device).float()
#      56     return torch.sin(sinusoid_inp), torch.cos(sinusoid_inp)
#      57
#
# KeyboardInterrupt:

# %% [markdown]
# This training loop is just a proof of concept - to show that even in the heaviest case, it still fits on a gpu.
# Depending on your finetuning task, you'll need to remove some parts.
# Below we explain how to modify the code to achieve the setup from the [LoRA paper](https://arxiv.org/pdf/2106.09685.pdf)
#
# If you wanna fine-tune a-la LoRA , please use the parameters from Table 11,12 and 15 as a starter:
#
# (1) Train only the adapter matrices from attention layers
#
# In the above example, we train all kinds of adapters, and also layernorm scales and biases. This is only useful for fine-tuning over reasonably large datasets over long time.
# For quick setups you should tag everything except **the attention adapters** as `requires_grad=False` -- or just don't feed them into Adam:
#
# ```
#
# params_for_optimizer = [
#     param for name, param in model.named_parameters()
#     if "attn" in name and "adapter" in name
# ]
# print("Trainiable params:", len(params_for_optimizer))
#
# # and after you verified it:
# for name, param in model.named_parameters():
#     if param not in params_for_optimizer:
#         print(f"Setting {name} requires_grad=False")
#         param.requires_grad = False
# ```
#
# An even better way is to only create adapters that you need by modifying the `add_adapters` function above:
# ```
# for name, module in model.named_modules():
#     if isinstance(module, (FrozenBNBLinear, FrozenBNBEmbedding)):
#         if "attn" in name:
#             print("Adding adapter to", name)
#
#             todo_initialize_adapters_like_in_notebook()
#         else:
#             print("Not adding adapter to", name)
# ```
# As a side-effect, that would actually somewhat reduce the memory usage and may let you fit a longer sequence (e.g. 256)
#
#
# (2) initialize the second adapter matrix with zeros
# ```
# for name, module in model.named_modules():
#     if hasattr(module, "adapter"):
#         print("Initializing", name)
#         nn.init.zeros_(module.adapter[1].weight)
#         # optional: scale adapter[0].weight by (LoRA_alpha / r)
# ```
#
# (3) use warmup and weight decay in Adam:
# ```
# optimizer = Adam8Bit(..., weight_decay=0.01)
# scheduler = transformers.get_linear_schedule_with_warmup(
#     optimizer, num_warmup_steps_from_paper(), expected_total_number_of_steps
# )
#
# actually_use_scheduler_in_training_loop()
# ```
#
# Finally, we recommend modifying training loop to track the training metrics, saving the best checkpoint, etc.
